# %%
import pandas as pd

df = pd.read_excel(r'C:\Users\pandy\Documents\UGM\Akademik\Semester 3\MII2201 Analisis Algoritma dan Kompleksitas\6\Tugas\heapSort.xlsx')
print(df)
# Out:
#        n        1        2        3       4        5       avg
# 0  10000  0.06993  0.07523  0.07432  0.0726  0.07145  0.072706
# 1  20000  0.11190  0.11360  0.11230  0.1113  0.11180  0.112180
# 2  30000  0.13750  0.14020  0.13730  0.1427  0.13900  0.139340
# 3  40000  0.14520  0.14480  0.14750  0.1469  0.14820  0.146520
# 4  50000  0.16800  0.15650  0.15370  0.1550  0.15480  0.157600

# %%
import matplotlib.pyplot as plt

x = df['n']
y = df['avg']
fig, ax = plt.subplots()
ax.plot(x, y, '-o', label = 'heap sort')
plt.xlabel('number of data (n)')
plt.ylabel('average running time (seconds)')
plt.title('Heap sort time complexity')
plt.xticks(rotation = 45)
plt.grid(linestyle = 'dotted')
plt.legend()
plt.savefig('heapSort.png', dpi = 300, bbox_inches = 'tight')

for i, txt in enumerate(y):
    ax.annotate(txt, (x[i], y[i]))

plt.show()
