# %%
import pandas as pd

df = pd.read_excel(r'C:\Users\pandy\Documents\UGM\Akademik\Semester 3\MII2201 Analisis Algoritma dan Kompleksitas\5\Tugas\AAK-5.xlsx')
print(df)
# Out:
#         n        1        2        3        4        5        6        7  \
# 0  100000    6.826    6.822    6.785    6.748    6.764    6.592    6.652
# 1  200000   26.420   26.440   26.410   26.580   26.460   26.600   26.480
# 2  300000   59.280   58.100   58.660   59.100   59.120   59.210   58.520
# 3  400000  103.400  103.400  104.600  104.300  104.500  104.900  104.500
# 4  500000  163.100  163.800  162.800  162.600  163.400  160.200  162.600
# 5  600000  232.900  232.700  234.500  232.500  234.700  235.200  235.100
#
#        avg
# 0    6.741
# 1   26.484
# 2   58.856
# 3  104.229
# 4  162.643
# 5  233.943

# %%
import matplotlib.pyplot as plt

x = df['n']
y = df['avg']
fig, ax = plt.subplots()
ax.plot(x, y, '-o')
plt.xlabel('number of data (n)')
plt.xticks(rotation = 45)
plt.ylabel('average running time (seconds)')
plt.title('Time complexity')
plt.savefig('loop.png', dpi = 300, bbox_inches = 'tight')

for i, txt in enumerate(y):
    ax.annotate(txt, (x[i], y[i]))

plt.show()
